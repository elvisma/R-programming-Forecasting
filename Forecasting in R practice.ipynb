# %%
library(xts)
library(zoo)
library(astsa)
# Out:
# Loading required package: zoo
#
# Attaching package: ‘zoo’
#
# The following objects are masked from ‘package:base’:
#
#     as.Date, as.Date.numeric
#
# Registered S3 method overwritten by 'xts':
#   method     from
#   as.zoo.xts zoo
# Error in library(astsa): there is no package called ‘astsa’
# Traceback:
#
# 1. library(astsa)

# %%
install.packages("astsa")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(astsa)

# %%
x<-arima.sim(model=list(order=c(1,0,0),ar=0.7), n=200)

# %%
plot(x)
# Out:
# plot without title

# %%
acf2(x)
# Out:
#       ACF   PACF
#  [1,]  0.71  0.71
#  [2,]  0.45 -0.10
#  [3,]  0.31  0.06
#  [4,]  0.22 -0.01
#  [5,]  0.18  0.05
#  [6,]  0.09 -0.11
#  [7,]  0.02 -0.01
#  [8,] -0.07 -0.11
#  [9,] -0.15 -0.09
# [10,] -0.18 -0.02
# [11,] -0.17  0.03
# [12,] -0.20 -0.14
# [13,] -0.18  0.09
# [14,] -0.18 -0.10
# [15,] -0.15  0.06
# [16,] -0.12 -0.06
# [17,] -0.16 -0.08
# [18,] -0.19 -0.12
# [19,] -0.16  0.06
# [20,] -0.12 -0.04
# [21,] -0.11 -0.04
# [22,] -0.04  0.09
# [23,] -0.01 -0.02
# [24,]  0.05  0.08
# [25,]  0.08  0.02
# Plot with title “Series:  x”

# %%
plot(diff(x))
# Out:
# plot without title

# %%
acf2(diff(x))
# Out:
#       ACF   PACF
#  [1,] -0.06 -0.06
#  [2,] -0.20 -0.20
#  [3,] -0.08 -0.11
#  [4,] -0.09 -0.16
#  [5,]  0.08  0.02
#  [6,] -0.03 -0.09
#  [7,]  0.02  0.01
#  [8,]  0.01 -0.02
#  [9,] -0.09 -0.09
# [10,] -0.07 -0.12
# [11,]  0.08  0.03
# [12,] -0.11 -0.18
# [13,]  0.05  0.01
# [14,] -0.06 -0.15
# [15,]  0.01 -0.02
# [16,]  0.09 -0.01
# [17,]  0.00  0.03
# [18,] -0.10 -0.15
# [19,] -0.04 -0.04
# [20,]  0.05 -0.04
# [21,] -0.08 -0.16
# [22,]  0.05 -0.05
# [23,] -0.05 -0.13
# [24,]  0.04 -0.07
# [25,]  0.05 -0.01
# Plot with title “Series:  diff(x)”

# %%
sarima(x,1,1,0)
sarima(x,1,0,0)
sarima(x,0,0,1)
sarima.for(x,n.ahead=20,1,0,0)
# Out:
# initial  value 0.083469
# iter   2 value 0.081501
# iter   3 value 0.081498
# iter   3 value 0.081498
# iter   3 value 0.081498
# final  value 0.081498
# converged
# initial  value 0.079389
# iter   2 value 0.079388
# iter   3 value 0.079387
# iter   3 value 0.079387
# iter   3 value 0.079387
# final  value 0.079387
# converged
# $fit
#
# Call:
# stats::arima(x = xdata, order = c(p, d, q), seasonal = list(order = c(P, D,
#     Q), period = S), xreg = constant, transform.pars = trans, fixed = fixed,
#     optim.control = list(trace = trc, REPORT = 1, reltol = tol))
#
# Coefficients:
#           ar1  constant
#       -0.0637   -0.0054
# s.e.   0.0720    0.0722
#
# sigma^2 estimated as 1.172:  log likelihood = -298.17,  aic = 602.33
#
# $degrees_of_freedom
# [1] 197
#
# $ttable
#          Estimate     SE t.value p.value
# ar1       -0.0637 0.0720 -0.8840  0.3778
# constant  -0.0054 0.0722 -0.0743  0.9408
#
# $AIC
# [1] 3.026803
#
# $AICc
# [1] 3.02711
#
# $BIC
# [1] 3.076451
# ...
